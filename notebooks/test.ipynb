# %%
# !pip install pdfplumber python-docx
# Out:
# Collecting pdfplumber
#   Using cached pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
# Collecting python-docx
#   Using cached python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\durge\anaconda3\lib\site-packages (from pdfplumber) (10.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\durge\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\durge\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (42.0.5)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\durge\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\durge\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\durge\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\durge\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Using cached pdfplumber-0.11.4-py3-none-any.whl (59 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached python_docx-1.1.2-py3-none-any.whl (244 kB)
# Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
# Installing collected packages: python-docx, pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0 python-docx-1.1.2

# %%
# !pip install unstructured[local-inference]
# Out:
# Requirement already satisfied: unstructured[local-inference] in c:\users\durge\anaconda3\lib\site-packages (0.15.13)
# Requirement already satisfied: chardet in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (4.0.0)
# Requirement already satisfied: filetype in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (0.4.27)
# Requirement already satisfied: lxml in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (5.2.1)
# Requirement already satisfied: nltk in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (0.9.0)
# Requirement already satisfied: requests in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (4.12.3)
# Requirement already satisfied: emoji in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (2.13.2)
# Requirement already satisfied: dataclasses-json in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (2024.4.27)
# Requirement already satisfied: langdetect in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (3.10.0)
# Requirement already satisfied: backoff in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (4.11.0)
# Requirement already satisfied: unstructured-client in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (0.25.9)
# Requirement already satisfied: wrapt in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (1.14.1)
# Requirement already satisfied: tqdm in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (4.66.4)
# Requirement already satisfied: psutil in c:\users\durge\appdata\roaming\python\python312\site-packages (from unstructured[local-inference]) (6.0.0)
# Requirement already satisfied: python-oxmsg in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (0.0.1)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[local-inference])
#   Using cached unstructured.pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-docx>=1.1.2 in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (1.1.2)
# Collecting pikepdf (from unstructured[local-inference])
#   Using cached pikepdf-9.3.0-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting python-pptx>=1.0.1 (from unstructured[local-inference])
#   Using cached python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (2.2.2)
# Requirement already satisfied: markdown in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (3.4.1)
# Collecting google-cloud-vision (from unstructured[local-inference])
#   Using cached google_cloud_vision-3.7.4-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting unstructured-inference==0.7.36 (from unstructured[local-inference])
#   Using cached unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: openpyxl in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (3.1.2)
# Collecting pdf2image (from unstructured[local-inference])
#   Using cached pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting onnx (from unstructured[local-inference])
#   Using cached onnx-1.16.2-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting pypandoc (from unstructured[local-inference])
#   Using cached pypandoc-1.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pdfminer.six in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (20231228)
# Collecting xlrd (from unstructured[local-inference])
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting pi-heif (from unstructured[local-inference])
#   Using cached pi_heif-0.18.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: networkx in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (3.2.1)
# Collecting effdet (from unstructured[local-inference])
#   Using cached effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: pypdf in c:\users\durge\anaconda3\lib\site-packages (from unstructured[local-inference]) (5.0.1)
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting python-multipart (from unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: huggingface-hub in c:\users\durge\anaconda3\lib\site-packages (from unstructured-inference==0.7.36->unstructured[local-inference]) (0.24.7)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting onnxruntime>=1.17.0 (from unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached onnxruntime-1.19.2-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: matplotlib in c:\users\durge\anaconda3\lib\site-packages (from unstructured-inference==0.7.36->unstructured[local-inference]) (3.8.4)
# Requirement already satisfied: torch in c:\users\durge\anaconda3\lib\site-packages (from unstructured-inference==0.7.36->unstructured[local-inference]) (2.4.1)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached timm-1.0.9-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: transformers>=4.25.1 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-inference==0.7.36->unstructured[local-inference]) (4.44.2)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\durge\anaconda3\lib\site-packages (from python-pptx>=1.0.1->unstructured[local-inference]) (10.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=1.0.1->unstructured[local-inference])
#   Using cached XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\durge\appdata\roaming\python\python312\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[local-inference]) (24.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\durge\anaconda3\lib\site-packages (from beautifulsoup4->unstructured[local-inference]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\durge\anaconda3\lib\site-packages (from dataclasses-json->unstructured[local-inference]) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\durge\anaconda3\lib\site-packages (from dataclasses-json->unstructured[local-inference]) (0.9.0)
# Requirement already satisfied: torchvision in c:\users\durge\anaconda3\lib\site-packages (from effdet->unstructured[local-inference]) (0.19.1)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[local-inference])
#   Using cached pycocotools-2.0.8-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[local-inference])
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[local-inference])
#   Using cached google_api_core-2.20.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-cloud-vision->unstructured[local-inference])
#   Using cached google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-vision->unstructured[local-inference])
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\durge\anaconda3\lib\site-packages (from google-cloud-vision->unstructured[local-inference]) (3.20.3)
# Requirement already satisfied: six in c:\users\durge\appdata\roaming\python\python312\site-packages (from langdetect->unstructured[local-inference]) (1.16.0)
# Requirement already satisfied: click in c:\users\durge\anaconda3\lib\site-packages (from nltk->unstructured[local-inference]) (8.1.7)
# Requirement already satisfied: joblib in c:\users\durge\anaconda3\lib\site-packages (from nltk->unstructured[local-inference]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\durge\anaconda3\lib\site-packages (from nltk->unstructured[local-inference]) (2023.10.3)
# Requirement already satisfied: et-xmlfile in c:\users\durge\anaconda3\lib\site-packages (from openpyxl->unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\durge\appdata\roaming\python\python312\site-packages (from pandas->unstructured[local-inference]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\durge\anaconda3\lib\site-packages (from pandas->unstructured[local-inference]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\durge\anaconda3\lib\site-packages (from pandas->unstructured[local-inference]) (2023.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\durge\anaconda3\lib\site-packages (from pdfminer.six->unstructured[local-inference]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\durge\anaconda3\lib\site-packages (from pdfminer.six->unstructured[local-inference]) (42.0.5)
# Collecting Deprecated (from pikepdf->unstructured[local-inference])
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: olefile in c:\users\durge\anaconda3\lib\site-packages (from python-oxmsg->unstructured[local-inference]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\durge\anaconda3\lib\site-packages (from requests->unstructured[local-inference]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\durge\anaconda3\lib\site-packages (from requests->unstructured[local-inference]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\durge\anaconda3\lib\site-packages (from requests->unstructured[local-inference]) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\durge\appdata\roaming\python\python312\site-packages (from tqdm->unstructured[local-inference]) (0.4.6)
# Requirement already satisfied: deepdiff>=6.0 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-client->unstructured[local-inference]) (8.0.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-client->unstructured[local-inference]) (0.27.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-client->unstructured[local-inference]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-client->unstructured[local-inference]) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\durge\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured[local-inference]) (1.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\durge\anaconda3\lib\site-packages (from unstructured-client->unstructured[local-inference]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\durge\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (1.16.0)
# Requirement already satisfied: orderly-set==5.2.2 in c:\users\durge\anaconda3\lib\site-packages (from deepdiff>=6.0->unstructured-client->unstructured[local-inference]) (5.2.2)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[local-inference])
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[local-inference])
#   Using cached grpcio-1.66.2-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[local-inference])
#   Using cached grpcio_status-1.66.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\durge\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\durge\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in c:\users\durge\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\durge\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\durge\anaconda3\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\durge\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[local-inference]) (0.14.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[local-inference])
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\durge\anaconda3\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[local-inference]) (6.0.1)
# Collecting coloredlogs (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: sympy in c:\users\durge\anaconda3\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference]) (1.12)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\durge\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\durge\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[local-inference]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\durge\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[local-inference]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\durge\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[local-inference]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\durge\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[local-inference]) (3.0.9)
# Requirement already satisfied: safetensors in c:\users\durge\anaconda3\lib\site-packages (from timm->unstructured-inference==0.7.36->unstructured[local-inference]) (0.4.5)
# Requirement already satisfied: filelock in c:\users\durge\anaconda3\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[local-inference]) (3.13.1)
# Requirement already satisfied: jinja2 in c:\users\durge\anaconda3\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[local-inference]) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\durge\anaconda3\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[local-inference]) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\durge\anaconda3\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[local-inference]) (69.5.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\durge\anaconda3\lib\site-packages (from transformers>=4.25.1->unstructured-inference==0.7.36->unstructured[local-inference]) (0.19.1)
# Requirement already satisfied: scipy in c:\users\durge\anaconda3\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[local-inference]) (1.13.1)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached iopath-0.1.10-py3-none-any.whl
# Requirement already satisfied: pdfplumber in c:\users\durge\anaconda3\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[local-inference]) (0.11.4)
# Requirement already satisfied: pycparser in c:\users\durge\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (2.21)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 (from google-cloud-vision->unstructured[local-inference])
#   Using cached protobuf-5.28.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\durge\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[local-inference]) (0.4.8)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting portalocker (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\durge\anaconda3\lib\site-packages (from jinja2->torch->unstructured-inference==0.7.36->unstructured[local-inference]) (2.1.3)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\durge\anaconda3\lib\site-packages (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[local-inference]) (4.30.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\durge\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference]) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[local-inference])
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\durge\appdata\roaming\python\python312\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.7.36->unstructured[local-inference]) (306)
# Using cached unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
# Using cached python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Using cached unstructured.pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Using cached effdet-0.4.1-py3-none-any.whl (112 kB)
# Using cached google_cloud_vision-3.7.4-py2.py3-none-any.whl (467 kB)
# Using cached onnx-1.16.2-cp312-cp312-win_amd64.whl (14.4 MB)
# Using cached pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Using cached pi_heif-0.18.0-cp312-cp312-win_amd64.whl (1.7 MB)
# Using cached pikepdf-9.3.0-cp312-cp312-win_amd64.whl (3.5 MB)
# Using cached pypandoc-1.13-py3-none-any.whl (21 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Using cached google_api_core-2.20.0-py3-none-any.whl (142 kB)
# Using cached google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached onnxruntime-1.19.2-cp312-cp312-win_amd64.whl (11.1 MB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached proto_plus-1.24.0-py3-none-any.whl (50 kB)
# Using cached pycocotools-2.0.8-cp312-cp312-win_amd64.whl (83 kB)
# Using cached timm-1.0.9-py3-none-any.whl (2.3 MB)
# Using cached XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
# Using cached python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached grpcio-1.66.2-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached grpcio_status-1.66.2-py3-none-any.whl (14 kB)
# Using cached protobuf-5.28.2-cp310-abi3-win_amd64.whl (431 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: flatbuffers, antlr4-python3-runtime, XlsxWriter, xlrd, unstructured.pytesseract, rsa, python-multipart, pyreadline3, pypandoc, protobuf, portalocker, pi-heif, pdf2image, opencv-python, omegaconf, grpcio, Deprecated, python-pptx, proto-plus, pikepdf, onnx, iopath, humanfriendly, googleapis-common-protos, google-auth, pycocotools, grpcio-status, google-api-core, coloredlogs, timm, onnxruntime, layoutparser, google-cloud-vision, effdet, unstructured-inference
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\durge\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\durge\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
